# %%
import shutil

TUR_DIR = "D:/Pythonfile/Audio-Deepfake-Detection/data/raw/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.eval.trl.txt"
DATA_DIR = "D:/Pythonfile/Audio-Deepfake-Detection/data/raw/ASVspoof2019_LA_eval/flac"
shutil.move(src, dst)
